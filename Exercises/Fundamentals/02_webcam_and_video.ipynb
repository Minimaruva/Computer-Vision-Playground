# %% [markdown]
# # Webcam and Video Loops
# Practice reading frames, handling loops, and writing simple overlays. Use TODOs to guide implementation.

# %%
# Setup
# - Install deps if needed: pip install opencv-python numpy
import cv2
import numpy as np

CAMERA_INDEX = 0  # adjust if multiple cameras
OUTPUT_PATH = 'capture.avi'  # used later for recording

# %%
# 1) Basic webcam loop
# TODO: open VideoCapture, verify isOpened, and loop reading frames
# TODO: show the frame; break on 'q' key press
# Remember to release capture and destroy windows
cap = None  # TODO: cv2.VideoCapture(CAMERA_INDEX)

# %%
# 2) Draw overlays on live frames
# TODO: inside the loop, draw a crosshair at the center and FPS text
# Hint: use cv2.line and cv2.putText; compute FPS from time delta
# TODO: add a simple grayscale preview (e.g., stack horizontally)
# Note: consider using np.hstack to combine color + gray converted back to BGR

# %%
# 3) Adjustable brightness/contrast
# TODO: add trackbars for alpha (contrast) and beta (brightness)
# Hint: cv2.createTrackbar on a named window; apply with cv2.convertScaleAbs
# TODO: show side-by-side original vs adjusted frame

# %%
# 4) Record to disk
# TODO: create a cv2.VideoWriter with same size as capture
# TODO: write frames while loop runs; stop cleanly on exit
# Hint: fourcc = cv2.VideoWriter_fourcc(*'XVID') and fps ~ cap.get(cv2.CAP_PROP_FPS) or 30
writer = None  # TODO

# %%
# 5) Simple motion highlighting
# TODO: maintain a running background (e.g., exponential moving average) and compute absdiff
# TODO: threshold the diff to get a motion mask and overlay it (colorize mask)
# Hint: cv2.accumulateWeighted for background, cv2.absdiff for delta
background = None  # TODO initialize with first frame as float

# %% [markdown]
# ## Stretch goals
# - Add keyboard shortcuts: 's' to snapshot a frame to disk.
# - Debounce FPS calculation with a moving window.
# - Experiment with different codecs (MJPG, XVID) and measure file sizes.
