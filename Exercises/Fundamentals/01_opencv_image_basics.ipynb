# %% [markdown]
# # OpenCV Image Fundamentals
# Goals: get comfortable reading images, inspecting pixels, and applying core transforms yourself before relying on higher-level APIs. Complete the TODOs in order.

# %%
# Setup
# - Install deps if needed: pip install opencv-python matplotlib numpy
# - Point IMAGE_PATH at a local sample image.
import cv2
import numpy as np
from matplotlib import pyplot as plt

IMAGE_PATH = 'path/to/your/image.jpg'  # TODO: update

# %%
# 1) Load image and inspect basics
# TODO: read the image with cv2.imread and store in img_bgr
# TODO: print type, dtype, shape, and min/max pixel values
# Hint: img_bgr.shape -> (H, W, C); cv2.imread loads BGR
img_bgr = None  # TODO

# %%
# 2) Show the image correctly
# TODO: convert BGR to RGB and show with matplotlib (plt.imshow)
# TODO: also try cv2.imshow in a window (remember cv2.waitKey + cv2.destroyAllWindows)
img_rgb = None  # TODO: cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

# %%
# 3) Pixel access and ROI
# TODO: grab a single pixel (y, x, channel) and print its BGR values
# TODO: slice a small region of interest (ROI) and compute its mean color
# Hint: ROI = img_bgr[y0:y1, x0:x1]
pixel_bgr = None  # TODO
roi = None  # TODO
roi_mean = None  # TODO: use np.mean with axis=(0,1)

# %%
# 4) Resize and aspect ratio
# TODO: resize the image to width=320 while keeping aspect ratio (compute new height)
# TODO: resize to a fixed square (256x256) and notice distortion
target_width = 320
new_height = None  # TODO: int(img_bgr.shape[0] * target_width / img_bgr.shape[1])
img_resized_keep = None  # TODO: cv2.resize(img_bgr, (target_width, new_height))
img_resized_square = None  # TODO: cv2.resize(img_bgr, (256, 256))

# %%
# 5) Color transforms
# TODO: convert to grayscale (cv2.cvtColor)
# TODO: apply a binary threshold at value 128 (cv2.threshold)
img_gray = None  # TODO
thresh_val = 128
_, img_binary = None, None  # TODO: cv2.threshold(img_gray, thresh_val, 255, cv2.THRESH_BINARY)

# %%
# 6) Drawing primitives
# TODO: copy img_rgb and draw a rectangle, circle, line, and putText
# Hint: cv2.rectangle, cv2.circle, cv2.line, cv2.putText (remember BGR colors)
canvas = None  # TODO: img_bgr.copy()

# %%
# 7) Simple arithmetic and blending
# TODO: darken or brighten using cv2.add / cv2.subtract with a scalar
# TODO: blend two images of same size with cv2.addWeighted (use img_bgr and img_resized_keep after matching sizes)
darker = None  # TODO
brighter = None  # TODO
blended = None  # TODO

# %% [markdown]
# ## Stretch goals
# - Implement a trackbar UI to adjust threshold live (cv2.createTrackbar).
# - Write a function to center-crop to a square, then resize to 256.
# - Time operations with %timeit to see cost of each step.
